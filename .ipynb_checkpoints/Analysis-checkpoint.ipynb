# %%
# Dependecies 
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import csv

# %%
cleaned_csv = 'Analysis.csv'

cleaned_df = pd.read_csv(cleaned_csv)

# %%
data_ana_df = cleaned_df
data_ana_df=data_ana_df.dropna()
group_data = data_ana_df.groupby(['Content Rating']).agg({'Budget': "mean" , "Gross Income": 'mean'})
group_data = group_data.astype('int64', copy=False)
group_data
group_data.plot(kind="bar",y="Budget", legend=False, title= "Budget by Content Ratings's", yticks=[0,60000000,50000000,40000000,30000000,20000000,10000000])
group_data.plot(kind="bar",y="Gross Income",  legend=False, title= "Gross Income by Content Rating's", yticks=[0,60000000,50000000,40000000,30000000,20000000,10000000])

# %%
df = cleaned_df


df = df.dropna(subset=['Genere']).reset_index(drop=True) 

splitted = df['Genere'].str.split('|')  
l = splitted.str.len()

x = df['IMDB Score']

#is necessary define new column name (divided) and change `df[]` to `x`  
df = pd.DataFrame({'divided': np.repeat(x, l), 'Genere':np.concatenate(splitted)}) 
print (df)
#define column for aggregate (divided), no x, because processing new df created by repeat 
d = {'mean':'Average Income'}
df1 = df.groupby('Genere')['divided'].mean().rename(columns=d).reset_index(name='return')

df1.plot.bar(x='Genere', y='return' , fontsize= 24, figsize=(20,10)) 
plt.xlabel("Genere")
# Out:
#       divided       Genere
# 0         7.9       Action
# 0         7.9    Adventure
# 0         7.9      Fantasy
# 0         7.9       Sci-Fi
# 1         7.1       Action
# 1         7.1    Adventure
# 1         7.1      Fantasy
# 2         6.8       Action
# 2         6.8    Adventure
# 2         6.8     Thriller
# 3         8.5       Action
# 3         8.5     Thriller
# 4         6.6       Action
# 4         6.6    Adventure
# 4         6.6       Sci-Fi
# 5         6.2       Action
# 5         6.2    Adventure
# 5         6.2      Romance
# 6         7.8    Adventure
# 6         7.8    Animation
# 6         7.8       Comedy
# 6         7.8       Family
# 6         7.8      Fantasy
# 6         7.8      Musical
# 6         7.8      Romance
# 7         7.5       Action
# 7         7.5    Adventure
# 7         7.5       Sci-Fi
# 8         7.5    Adventure
# 8         7.5       Family
# ...       ...          ...
# 3758      6.3      Romance
# 3759      7.5        Drama
# 3760      7.6       Comedy
# 3760      7.6      Romance
# 3761      4.1      Western
# 3762      7.8       Comedy
# 3763      7.3       Comedy
# 3763      7.3        Drama
# 3764      5.7       Action
# 3764      5.7        Crime
# 3764      5.7        Drama
# 3764      5.7     Thriller
# 3765      7.1       Comedy
# 3765      7.1        Drama
# 3766      6.1       Comedy
# 3766      6.1        Crime
# 3766      6.1       Horror
# 3767      6.9        Drama
# 3767      6.9        Music
# 3767      6.9      Romance
# 3768      7.5        Drama
# 3769      7.0        Drama
# 3769      7.0       Sci-Fi
# 3769      7.0     Thriller
# 3770      6.9       Action
# 3770      6.9        Crime
# 3770      6.9        Drama
# 3770      6.9      Romance
# 3770      6.9     Thriller
# 3771      6.6  Documentary
#
# [11271 rows x 2 columns]
# Text(0.5,0,'Genere')

# %%
df = cleaned_df


df = df.dropna(subset=['Genere']).reset_index(drop=True) 

splitted = df['Genere'].str.split('|')  
l = splitted.str.len()

x = df['Number of User Votes']

#is necessary define new column name (divided) and change `df[]` to `x`  
df = pd.DataFrame({'divided': np.repeat(x, l), 'Genere':np.concatenate(splitted)}) 
print (df)
#define column for aggregate (divided), no x, because processing new df created by repeat 
d = {'mean':'Average Income'}
df1 = df.groupby('Genere')['divided'].mean().rename(columns=d).reset_index(name='return')

df1.plot.bar(x='Genere', y='return' , fontsize= 24, figsize=(20,10)) 
plt.xlabel("Genere")
# Out:
#       divided       Genere
# 0      886204       Action
# 0      886204    Adventure
# 0      886204      Fantasy
# 0      886204       Sci-Fi
# 1      471220       Action
# 1      471220    Adventure
# 1      471220      Fantasy
# 2      275868       Action
# 2      275868    Adventure
# 2      275868     Thriller
# 3     1144337       Action
# 3     1144337     Thriller
# 4      212204       Action
# 4      212204    Adventure
# 4      212204       Sci-Fi
# 5      383056       Action
# 5      383056    Adventure
# 5      383056      Romance
# 6      294810    Adventure
# 6      294810    Animation
# 6      294810       Comedy
# 6      294810       Family
# 6      294810      Fantasy
# 6      294810      Musical
# 6      294810      Romance
# 7      462669       Action
# 7      462669    Adventure
# 7      462669       Sci-Fi
# 8      321795    Adventure
# 8      321795       Family
# ...       ...          ...
# 3758    11816      Romance
# 3759     6246        Drama
# 3760     2631       Comedy
# 3760     2631      Romance
# 3761      143      Western
# 3762   181749       Comedy
# 3763    11550       Comedy
# 3763    11550        Drama
# 3764    47502       Action
# 3764    47502        Crime
# 3764    47502        Drama
# 3764    47502     Thriller
# 3765    15103       Comedy
# 3765    15103        Drama
# 3766    16792       Comedy
# 3766    16792        Crime
# 3766    16792       Horror
# 3767     3924        Drama
# 3767     3924        Music
# 3767     3924      Romance
# 3768     4555        Drama
# 3769    72639        Drama
# 3769    72639       Sci-Fi
# 3769    72639     Thriller
# 3770    52055       Action
# 3770    52055        Crime
# 3770    52055        Drama
# 3770    52055      Romance
# 3770    52055     Thriller
# 3771     4285  Documentary
#
# [11271 rows x 2 columns]
# Text(0.5,0,'Genere')
